# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams.update({'font.size': 15})
plt.rc('font',family='serif', serif=['Arial'])
frameon=False
CB91_Green = '#47DBCD'
CB91_Amber = '#F5B14C'
CB91_Blue = '#2CBDFE'
CB91_Pink = '#F3A0F2'
CB91_Purple = '#9D2EC5'
CB91_Violet = '#661D98'
CB91_Amber = '#F5B14C'

# %%
# changing color
lga = [1, 0.95]
lga_error = [0, 0.05]
gcbc = [0.35, 0.1]
gcbc_error = [0.1, 0.1]

figure1 = plt.bar(range(len(lga)), lga, yerr=lga_error, align='edge', width=0.4, label='LGA', color=CB91_Green)
figure2 = plt.bar(range(len(gcbc)), gcbc, yerr=gcbc_error, align='edge', width=-0.4, label='GCBC', color=CB91_Amber)

#plt.xticks(np.arange(9), ['red heart', 'heart', 'tiger', 'letter', 'consonant', 'vowel', 'letter', 'alphabet', 'kitchen'])
plt.xticks(np.arange(2), ['heart','letter'])

plt.legend(loc='right')

plt.title("Texture Shift")
plt.xlabel("Task")
plt.ylabel("Success")
sns.despine()

plt.savefig('q2_state_color.pdf', format="pdf", bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 gcbc = [0.35, 0.1]
#       5 gcbc_error = [0.1, 0.1]
# ----> 7 figure1 = plt.bar(range(len(lga)), lga, yerr=lga_error, align='edge', width=0.4, label='LGA', color=CB91_Green)
#       8 figure2 = plt.bar(range(len(gcbc)), gcbc, yerr=gcbc_error, align='edge', width=-0.4, label='GCBC', color='gray')
#      10 #plt.xticks(np.arange(9), ['red heart', 'heart', 'tiger', 'letter', 'consonant', 'vowel', 'letter', 'alphabet', 'kitchen'])
#
# NameError: name 'plt' is not defined

# %%
# distractors
lga = [1, 0.95]
lga_error = [0, 0.05]
gcbc = [0.05, 0]
gcbc_error = [0.05, 0]

figure1 = plt.bar(range(len(lga)), lga, yerr=lga_error, align='edge', width=0.4, label='LGA', color=CB91_Green)
figure2 = plt.bar(range(len(gcbc)), gcbc, yerr=gcbc_error, align='edge', width=-0.4, label='GCBC', color=CB91_Amber)

#plt.xticks(np.arange(9), ['red heart', 'heart', 'tiger', 'letter', 'consonant', 'vowel', 'letter', 'alphabet', 'kitchen'])
plt.xticks(np.arange(2), ['heart','letter'])

plt.legend(loc='right')

plt.title("New Distractors")
plt.xlabel("Task")
plt.ylabel("Success")
sns.despine()

plt.savefig('q2_state_distractor.pdf', format="pdf", bbox_inches="tight")
plt.show()

# %%
# Multitask
gcbc = [0.2, 0.1, 0]
gcbc_error = [0.15, 0.05,0]
lga = [0.9,1.,0.9]
lga_error = [0.05, 0, 0.1]

figure1 = plt.bar(range(len(lga)), lga, yerr=lga_error, align='edge', width=0.4, label='LGA', color=CB91_Green)
figure2 = plt.bar(range(len(gcbc)), gcbc, yerr=gcbc_error, align='edge', width=-0.4, label='GCBC', color=CB91_Amber)

plt.xticks(np.arange(3), ['bowl','star','find in kitchen'])

plt.legend(loc='right')

plt.title("Multi-Task Ambiguity")
plt.xlabel("Task")
plt.ylabel("Success")
sns.despine()

plt.savefig('q3_lang_ambiguity.pdf', format="pdf", bbox_inches="tight")
plt.show()
