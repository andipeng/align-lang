# %%
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# personalization
dsp = [1, 1, 0.9]
dsp_error = [0, 0, 0.1]
lm = [0.2, 0.3, 0.55]
lm_error = [0.1, 0.1, 0.25]

figure1 = plt.bar(range(len(dsp)), dsp, yerr=dsp_error, align='edge', width=0.4, label='DSP (ours)', color='green')
figure2 = plt.bar(range(len(lm)), lm, yerr=lm_error, align='edge', width=-0.4, label='LM-only', color='gray')

#plt.xticks(np.arange(9), ['red heart', 'heart', 'tiger', 'letter', 'consonant', 'vowel', 'letter', 'alphabet', 'kitchen'])
plt.xticks(np.arange(3), ['favorite color','dream patio', 'letter in name'])

plt.legend()

plt.title("Alignment to Personalized Objectives")
plt.xlabel("Task")
plt.ylabel("Success")

plt.savefig('personalization.pdf', format="pdf", bbox_inches="tight")
plt.show()
