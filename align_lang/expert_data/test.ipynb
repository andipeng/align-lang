# %%
import pickle
import numpy as np
from matplotlib import pyplot as plt

# %%
trajs = pickle.load(open('trajs.pkl','rb'))

# %%
plt.imshow(trajs[1]['obs'][0])

# %%
plt.imshow(trajs[1]['ilga_obs'][0])

# %%
plt.imshow(trajs[1]['lga_obs'][0])

# %%
trajs[1]['acts'][0]
# Out:
# array([ 0.35    , -0.259375,  0.      ,  0.      ,  0.      ,  1.      ,
#         0.63125 ,  0.13125 ,  0.      ,  0.      ,  0.      ,  1.      ],
#       dtype=float32)
